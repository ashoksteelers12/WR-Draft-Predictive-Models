# %%
import csv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from ripser import ripser
from persim import plot_diagrams

# %%
# %store -r WR_Prospects_2018

# %%
for i in range(len(WR_Prospects_2018)):
    prospect = str(i+1) + ") " + WR_Prospects_2018[i][0] 
    print(prospect)
# Out:
# 1) Marcell Ateman
# 2) Braxton Berrios
# 3) Deontay Burnett
# 4) Deon Cain
# 5) Antonio Callaway
# 6) Darren Carrington II
# 7) Dylan Cantrell
# 8) D.J. Chark
# 9) Simmie Cobbs
# 10) Keke Coutee
# 11) Robert Foster
# 12) Daesean Hamilton
# 13) Quadree Henderson
# 14) Christian Kirk
# 15) Chris Lacy
# 16) Jordan Lasley
# 17) Allen Lazard
# 18) Martin Tavares
# 19) Ray-Ray McCloud
# 20) Steven Mitchell
# 21) D.J. Moore
# 22) J'mon Moore
# 23) Dante Pettis
# 24) Cam Phillips
# 25) Byron Pringle
# 26) Calvin Ridley
# 27) Equanimeous St. Brown
# 28) Auden Tate
# 29) James Washington
# 30) Jester Weah
# 31) Ka'ruan White
# 32) Javon Wims

# %%
WR_Prospects_2018_Updated = []

# %%
# Marcell Ateman
filename = 'Game-Stats-2018/' + WR_Prospects_2018[0][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[0])):
    temp.append(WR_Prospects_2018[0][i])
temp.append(5)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Braxton Berrios
filename = 'Game-Stats-2018/' + WR_Prospects_2018[1][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[1])):
    temp.append(WR_Prospects_2018[1][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Deontay Burnett
filename = 'Game-Stats-2018/' + WR_Prospects_2018[2][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[2])):
    temp.append(WR_Prospects_2018[2][i])
temp.append(5)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Deon Cain
filename = 'Game-Stats-2018/' + WR_Prospects_2018[3][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[3])):
    temp.append(WR_Prospects_2018[3][i])
temp.append(7)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Antonio Callaway
filename = 'Game-Stats-2018/' + WR_Prospects_2018[4][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[4])):
    temp.append(WR_Prospects_2018[4][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Darren Carrington II
filename = 'Game-Stats-2018/' + WR_Prospects_2018[5][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[5])):
    temp.append(WR_Prospects_2018[5][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Dylan Cantrell
filename = 'Game-Stats-2018/' + WR_Prospects_2018[6][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[6])):
    temp.append(WR_Prospects_2018[6][i])
temp.append(2)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# D.J Chark
filename = 'Game-Stats-2018/' + WR_Prospects_2018[7][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[7])):
    temp.append(WR_Prospects_2018[7][i])
temp.append(2)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Simmie Cobbs
filename = 'Game-Stats-2018/' + WR_Prospects_2018[8][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[8])):
    temp.append(WR_Prospects_2018[8][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Keke Coutee
filename = 'Game-Stats-2018/' + WR_Prospects_2018[9][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[9])):
    temp.append(WR_Prospects_2018[9][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Robert Foster
filename = 'Game-Stats-2018/' + WR_Prospects_2018[10][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[10])):
    temp.append(WR_Prospects_2018[10][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Daesean Hamilton
filename = 'Game-Stats-2018/' + WR_Prospects_2018[11][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[11])):
    temp.append(WR_Prospects_2018[11][i])
temp.append(5)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Quadree Henderson
filename = 'Game-Stats-2018/' + WR_Prospects_2018[12][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[12])):
    temp.append(WR_Prospects_2018[12][i])
temp.append(6)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Christian Kirk
filename = 'Game-Stats-2018/' + WR_Prospects_2018[13][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[13])):
    temp.append(WR_Prospects_2018[13][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Chris Lacy
filename = 'Game-Stats-2018/' + WR_Prospects_2018[14][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[14])):
    temp.append(WR_Prospects_2018[14][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Jordan Lasley
filename = 'Game-Stats-2018/' + WR_Prospects_2018[15][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[15])):
    temp.append(WR_Prospects_2018[15][i])
temp.append(1)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Allen Lazard
filename = 'Game-Stats-2018/' + WR_Prospects_2018[16][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[16])):
    temp.append(WR_Prospects_2018[16][i])
temp.append(5)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Martin Tavares
filename = 'Game-Stats-2018/' + WR_Prospects_2018[17][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[17])):
    temp.append(WR_Prospects_2018[17][i])
temp.append(5)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Ray-Ray McCloud
filename = 'Game-Stats-2018/' + WR_Prospects_2018[18][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[18])):
    temp.append(WR_Prospects_2018[18][i])
temp.append(7)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Steven Mitchell
filename = 'Game-Stats-2018/' + WR_Prospects_2018[19][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[19])):
    temp.append(WR_Prospects_2018[19][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# D.J. Moore
filename = 'Game-Stats-2018/' + WR_Prospects_2018[20][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[20])):
    temp.append(WR_Prospects_2018[20][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# J'mon Moore
filename = 'Game-Stats-2018/' + WR_Prospects_2018[21][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[21])):
    temp.append(WR_Prospects_2018[21][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Dante Pettis
filename = 'Game-Stats-2018/' + WR_Prospects_2018[22][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[22])):
    temp.append(WR_Prospects_2018[22][i])
temp.append(6)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Cam Phillips
filename = 'Game-Stats-2018/' + WR_Prospects_2018[23][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[23])):
    temp.append(WR_Prospects_2018[23][i])
temp.append(4)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Byron Pringle
filename = 'Game-Stats-2018/' + WR_Prospects_2018[24][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[24])):
    temp.append(WR_Prospects_2018[24][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Calvin Ridley
filename = 'Game-Stats-2018/' + WR_Prospects_2018[25][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[25])):
    temp.append(WR_Prospects_2018[25][i])
temp.append(5)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Equanimeous St. Brown
filename = 'Game-Stats-2018/' + WR_Prospects_2018[26][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[26])):
    temp.append(WR_Prospects_2018[26][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Auden Tate
filename = 'Game-Stats-2018/' + WR_Prospects_2018[27][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[27])):
    temp.append(WR_Prospects_2018[27][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# James Washington
filename = 'Game-Stats-2018/' + WR_Prospects_2018[28][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[28])):
    temp.append(WR_Prospects_2018[28][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Jester Weah
filename = 'Game-Stats-2018/' + WR_Prospects_2018[29][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[29])):
    temp.append(WR_Prospects_2018[29][i])
temp.append(3)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Ka'ruan White 
filename = 'Game-Stats-2018/' + WR_Prospects_2018[30][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[30])):
    temp.append(WR_Prospects_2018[30][i])
temp.append(5)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# Javon Wims
filename = 'Game-Stats-2018/' + WR_Prospects_2018[31][0] + '.csv'
df = pd.read_csv(filename)
new_df = df[['Rec','Yds','TD']].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(new_df[:, 0], new_df[:, 1], new_df[:,2])
plt.show()

ph = np.zeros((len(new_df), 3))
for i in range(len(new_df)):
    ph[i][0] = new_df[i][0]
    ph[i][1] = new_df[i][1]
    ph[i][2] = new_df[i][2]
diagrams = ripser(ph, thresh=999, maxdim=2)['dgms']
plot_diagrams(diagrams, xy_range=[-2,5,-1,5], show=True)

# %%
temp = []
for i in range(len(WR_Prospects_2018[31])):
    temp.append(WR_Prospects_2018[31][i])
temp.append(9)
temp.append(0)
temp.append(0)
WR_Prospects_2018_Updated.append(temp)

# %%
# %store WR_Prospects_2018_Updated
del WR_Prospects_2018_Updated
# Out:
# Stored 'WR_Prospects_2018_Updated' (list)
