# %%
# Store All WRs (Name, Conference, College, Year, Grade, Round #, Class)

WR_Prospects = []

# 2018 NFL Draft
WR_Prospects.append(['Marcell Ateman','Big 12','Oklahoma State',2018,6.10,7,5])
WR_Prospects.append(['Braxton Berrios','ACC','Miami',2018,5.90,6,4])
WR_Prospects.append(['Deontay Burnett','Pac 12','USC',2018,5.90,0,3])
WR_Prospects.append(['Deon Cain','ACC','Clemson',2018,6.30,6,3])
WR_Prospects.append(['Antonio Callaway','SEC','Florida',2018,6.10,4,3])
WR_Prospects.append(['Darren Carrington II','Pac 12','Utah',2018,5.90,0,4])
WR_Prospects.append(['Dylan Cantrell','Big 12','Texas Tech',2018,5.60,6,5])
WR_Prospects.append(['D.J. Chark','SEC','LSU',2018,6.30,2,4])
WR_Prospects.append(['Simmie Cobbs','Big 10','Indiana',2018,5.80,0,4])
WR_Prospects.append(['Keke Coutee','Big 12','Texas Tech',2018,6.10,4,3])
WR_Prospects.append(['Robert Foster','SEC','Alabama',2018,5.40,0,5])
WR_Prospects.append(['Daesean Hamilton','Big 10','Penn State',2018,6.20,4,5])
WR_Prospects.append(['Quadree Henderson','ACC','Pittsburgh',2018,5.80,0,4])
WR_Prospects.append(['Christian Kirk','SEC','Texas A&M',2018,6.30,2,4])
WR_Prospects.append(['Chris Lacy','Big 12','Oklahoma State',2018,5.40,0,4])
WR_Prospects.append(['Jordan Lasley','Pac 12','UCLA',2018,5.90,5,4])
WR_Prospects.append(['Allen Lazard','Big 12','Iowa State',2018,5.90,0,4])
WR_Prospects.append(['Martin Tavares','Pac 12','Washington State',2018,5.40,0,3])
WR_Prospects.append(['Ray-Ray McCloud','ACC','Clemson',2018,5.40,6,3])
WR_Prospects.append(['Steven Mitchell','Pac 12','USC',2018,5.40,0,5])
WR_Prospects.append(['D.J. Moore','Big 10','Maryland',2018,6.30,1,3])
WR_Prospects.append(['J\'mon Moore','SEC','Missouri',2018,6.10,4,4])
WR_Prospects.append(['Dante Pettis','Pac 12','Washington',2018,6.20,2,4])
WR_Prospects.append(['Cam Phillips','ACC','Virginia Tech',2018,5.40,0,4])
WR_Prospects.append(['Byron Pringle','Big 12','Kansas State',2018,5.80,0,3])
WR_Prospects.append(['Calvin Ridley','SEC','Alabama',2018,6.80,1,3])
WR_Prospects.append(['Equanimeous St. Brown','ACC','Notre Dame',2018,6.20,6,3])
WR_Prospects.append(['Auden Tate','ACC','Florida State',2018,5.90,7,3])
WR_Prospects.append(['James Washington','Big 12','OKlahoma State',2018,6.20,2,4])
WR_Prospects.append(['Jester Weah','ACC','Pittsburgh',2018,5.80,0,4])
WR_Prospects.append(['Ka\'ruan White','Big 12','West Virginia',2018,5.60,0,4])
WR_Prospects.append(['Javon Wims','SEC','Georgia',2018,5.80,7,4])

# 2019 NFL Draft
WR_Prospects.append(['J.J. Arcega-Whiteside','Pac 12','Stanford',2019,6.20,2,4])
WR_Prospects.append(['Miles Boykin','ACC','Notre Dame',2019,6.20,3,4])
WR_Prospects.append(['A.J. Brown','SEC','Ole Miss',2019,6.70,2,3])
WR_Prospects.append(['Marquise Brown','Big 12','Oklahoma',2019,6.70,1,3])
WR_Prospects.append(['Hakeem Butler','Big 12','Iowa State',2019,6.20,4,4])
WR_Prospects.append(['Parris Campbell','Big 10','Ohio State',2019,6.70,2,4])
WR_Prospects.append(['Jamal Custis','ACC','Syracuse',2019,5.60,0,5])
WR_Prospects.append(['Felton Davis','Big 10','Michigan State',2019,5.90,0,4])
WR_Prospects.append(['Ryan Davis','SEC','Auburn',2019,5.40,0,4])
WR_Prospects.append(['Johnnie Dixon','Big 10','Ohio State',2019,5.40,0,5])
WR_Prospects.append(['Terry Godwin','SEC','Georgia',2019,5.60,7,4])
WR_Prospects.append(['Kelvin Harmon','ACC','NC State',2019,6.10,6,3])
WR_Prospects.append(['N\'Keal Harry','Pac 12','Arizona State',2019,6.30,1,3])
WR_Prospects.append(['Lil\'jordan Humphrey','Big 12','Texas',2019,5.60,0,3])
WR_Prospects.append(['Jalen Hurd','Big 12','Baylor',2019,6.20,3,4])
WR_Prospects.append(['Gary Jennings','Big 12','West Virginia',2019,5.90,4,4])
WR_Prospects.append(['DaMarkus Lodge','SEC','Ole Miss',2019,5.80,0,4])
WR_Prospects.append(['Terry McLaurin','Big 10','Ohio State',2019,6.10,3,5])
WR_Prospects.append(['D.K. Metcalf','SEC','Ole Miss',2019,6.80,2,3])
WR_Prospects.append(['Dillon Mitchell','Pac 12','Oregon',2019,5.90,7,3])
WR_Prospects.append(['Stanley Morgan','Big 10','Nebraska',2019,6.10,0,4])
WR_Prospects.append(['Nyqwan Murray','ACC','Florida State',2019,5.50,0,4])
WR_Prospects.append(['Hunter Renfrow','ACC','Clemson',2019,6.10,5,5])
WR_Prospects.append(['Riley Ridley','SEC','Georgia',2019,6.30,4,3])
WR_Prospects.append(['Deebo Samuel','SEC','South Carolina',2019,6.40,2,5])
WR_Prospects.append(['David Sills','Big 12','West Virginia',2019,5.90,0,4])
WR_Prospects.append(['Darius Slayton','SEC','Auburn',2019,6.20,5,4])
WR_Prospects.append(['Jaylen Smith','ACC','Louisville',2019,5.60,0,4])
WR_Prospects.append(['Antoine Wesley','Big 12','Texas Tech',2019,5.90,0,3])

# 2020 NFL Draft - Test Set
WR_Prospects.append(['Brandon Aiyuk','Pac 12','Arizona State',2020,6.38,1,4])
WR_Prospects.append(['Lynn Bowden','SEC','Kentucky',2020,6.24,3,3,])
WR_Prospects.append(['Tony Brown','Pac 12','Colorado',2020,5.69,0,5])
WR_Prospects.append(['Lawrence Cager','SEC','Georgia',2020,5.87,0,5])
WR_Prospects.append(['Marquez Callaway','SEC','Tennessee',2020,5.83,0,4])
WR_Prospects.append(['Quintez Cephus','Big 10','Wisconsin',2020,5.99,5,3])
WR_Prospects.append(['Chase Claypool','ACC','Notre Dame',2020,6.32,2,4])
WR_Prospects.append(['Tyrie Cleveland','SEC','Florida',2020,5.61,7,4])
WR_Prospects.append(['Quartney Davis','SEC','Texas A&M',2020,5.95,0,4])
WR_Prospects.append(['Devin Duvernay','Big 12','Texas',2020,6.00,3,4])
WR_Prospects.append(['Bryan Edwards','SEC','South Carolina',2020,6.34,3,4])
WR_Prospects.append(['Chris Finke','ACC','Notre Dame',2020,5.54,0,5])
WR_Prospects.append(['Aaron Fuller','ACC','Washington',2020,5.40,0,4])
WR_Prospects.append(['Stephen Guidry','SEC','Mississippi State',2020,5.60,0,4])
WR_Prospects.append(['KJ Hamler','Big 10','Penn State',2020,6.33,2,3])
WR_Prospects.append(['Tee Higgins','ACC','Clemson',2020,6.37,2,3])
WR_Prospects.append(['K.J. Hill','Big 10','Ohio State',2020,5.99,7,5])
WR_Prospects.append(['Isaiah Hodgins','Pac 12','Oregon State',2020,6.14,6,3])
WR_Prospects.append(['Trishton Jackson','ACC','Syracuse',2020,6.00,0,4])
WR_Prospects.append(['Justin Jefferson','SEC','LSU',2020,6.46,1,3])
WR_Prospects.append(['Van Jefferson','SEC','Florida',2020,6.27,2,5])
WR_Prospects.append(['Jauan Jennings','SEC','Tennessee',2020,5.40,7,5])
WR_Prospects.append(['Jerry Jeudy','SEC','Alabama',2020,6.77,1,3])
WR_Prospects.append(['Collin Johnson','Big 12','Texas',2020,5.95,5,4])
WR_Prospects.append(['Juwan Johnson','Pac 12','Oregon',2020,5.68,0,5])
WR_Prospects.append(['Tyler Johnson','Big 10','Minnesota',2020,5.99,5,4])
WR_Prospects.append(['Ceedee Lamb','Big 12','Oklahoma',2020,6.81,1,3])
WR_Prospects.append(['Kalija Lipscomb','SEC','Vanderbilt',2020,5.89,0,4])
WR_Prospects.append(['Austin Mack','Big 10','Ohio State',2020,5.66,0,4])
WR_Prospects.append(['Denzel Mims','Big 12','Baylor',2020,6.33,2,4])
WR_Prospects.append(['K.J. Osborn','ACC','Miami',2020,5.53,5,5])
WR_Prospects.append(['Dezmon Patmon','Pac 12','Washington State',2020,5.64,6,4])
WR_Prospects.append(['Donovan Peoples-Jones','Big 10','Michigan',2020,5.94,6,3])
WR_Prospects.append(['Michael Pittman','Pac 12','USC',2020,6.38,2,4])
WR_Prospects.append(['Jalen Reagor','Big 12','TCU',2020,6.36,1,3])
WR_Prospects.append(['Joe Reed','ACC','Virgina',2020,5.89,5,4])
WR_Prospects.append(['Kendrick Rogers','SEC','Texas A&M',2020,5.40,0,4])
WR_Prospects.append(['Henry Ruggs III','SEC','Alabama',2020,6.72,1,3])
WR_Prospects.append(['Laviska Shenault Jr.','ACC','Colorado',2020,6.35,2,3])
WR_Prospects.append(['Darrell Stewart','Big 10','Michigan State',2020,5.40,0,5])
WR_Prospects.append(['Freddie Swain','SEC','Florida',2020,5.80,6,4])
WR_Prospects.append(['Jeff Thomas','ACC','Miami',2020,5.60,0,3])
WR_Prospects.append(['Ben Victor','Big 10','Ohio State',2020,5.50,0,4])
WR_Prospects.append(['Cody White','Big 10','Michigan State',2020,5.40,0,3])

# %store WR_Prospects
# Out:
# Stored 'WR_Prospects' (list)

# %%
WR_Prospects_2018 = []
WR_Prospects_2019 = []
WR_Prospects_2020 = []

for i in range(len(WR_Prospects)):
    if WR_Prospects[i][3] == 2018:
        WR_Prospects_2018.append(WR_Prospects[i])
    if WR_Prospects[i][3] == 2019:
        WR_Prospects_2019.append(WR_Prospects[i])
    if WR_Prospects[i][3] == 2020:
        WR_Prospects_2020.append(WR_Prospects[i])
                
# %store WR_Prospects_2018 WR_Prospects_2019 WR_Prospects_2020
# Out:
# Stored 'WR_Prospects_2018' (list)
# Stored 'WR_Prospects_2019' (list)
# Stored 'WR_Prospects_2020' (list)

# %%
del WR_Prospects
del WR_Prospects_2018, WR_Prospects_2019, WR_Prospects_2020
